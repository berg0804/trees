# %%
from graphviz import Digraph


# Create a new directed graph

graph = Digraph()
graph.node("1", "Roberto Luongo",fillcolor="#00205B",style="filled", fontcolor="white", width="3.5", height="3.5", fontsize="30")
graph.node("2", "Mark Parrish")
graph.node("3", "Oleg Kvasha")
graph.node("4", "Olli Jokinen")
graph.node("5", "Lukas Krajicek")
graph.node("6", "Sergei Shirokov\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("7", "Todd Bertuzzi")
graph.node("8", "Bryan Allen")
graph.node("9", "Alex Auld")
graph.node("10", "Jacob Markstrom\nCalgary Flames",fillcolor="#D2001C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("11", "Shawn Matthias")
graph.node("12", "Steven Anthony")
graph.node("13", "Denis Grebeshkov")
graph.node("14", "Jeff Tambellini")
graph.node("15", "Brent Sopel")
graph.node("16", "Brett Bennett\n(Draft Pick)")
graph.node("17", "Brad Marchand\n(Draft Pick)\nBoston Bruins",fillcolor="#FFB81C",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("18", "Keith Ballard")
graph.node("19", "Nick Boynton")
graph.node("20", "Jared Staal\n(Draft Pick)")
graph.node("21", "Matthew Lombardi")
graph.node("22", "Brandon Prust")
graph.node("23", "Brandon Gormley\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("24", "Josh Birkholz\n(Draft Pick)")
graph.node("25", "Ales Kotalik")
graph.node("26", "Chris Higgins")
graph.node("28", "Brendan Leipsic\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("29", "Cody Franson\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("30", "Mike Santorelli")
graph.node("31", "Joakim Lindstrom\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("32", "Nicholas Mattinen\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("33", "Travis Konecny\n(Draft Pick)\nPhiladelphia Flyers",fillcolor="#F74902",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("34", "Shane O'Brien")
graph.node("35", "Michel Ouellet")
graph.node("36", "Juraj Simek\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("37", "Mike Duco")
graph.node("38", "Nick Spaling\n(Draft Pick)")
graph.node("39", "Sergei Samsonov")
graph.node("40", "Rene Bourque")
graph.node("41", "Nate DiCasmirro")
graph.node("42", "Jeff Costello")
graph.node("43", "Mark Stone\n(Draft Pick)\nVegas Golden Knights",fillcolor="#B4975A",style="filled", fontcolor="white",width="3.0", height="3.0", fontsize="25")
graph.node("44", "Colin Smith")
graph.node("45", "Keaton Middleton\n(Draft Pick)\nColorado Avalanche",fillcolor="#6F263D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("46", "Marc-Andre Bergeron")
graph.node("47", "Kirill Petrov\n(Draft Pick)\Free Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("48", "Curtis Hamilton\n(Draft Pick)\Free Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("49", "Wayne Simmonds\n(Draft Pick)\nToronto Maple Leafs",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("50", "Justin Jokinen\n(Draft Pick)")
graph.node("51", "Marty Reasoner")
graph.node("52", "Joey Crabb")
graph.node("53", "Jeremy Morin")
graph.node("54", "Kevin Hayes\n(Draft Pick)\nPhiladelphia Flyers",fillcolor="#F74902",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("55", "Justin Holl\n(Draft Pick)\nToronto Maple Leafs",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("56", "Dustin Byfuglien")
graph.node("57", "Ben Eager")
graph.node("58", "Akim Aliu")
graph.node("59", "Nigel Dawes")
graph.node("60", "Ben Maxwell\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("61", "Olivier Archambault\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("62", "Victor Oreskovich")
graph.node("63", "Steve Bernier")
graph.node("64", "Michael Grabner")
graph.node("65", "Quinton Howden\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("66", "Justin Weller\n(Draft Pick)")
graph.node("67", "Colby Robak\n(Draft Pick\nFree Agent)",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("68", "Louis Domingue\n(Draft Pick)\nNew York Rangers",fillcolor="#0038A8",style="filled", fontcolor="white",width="3.0", height="3.0", fontsize="25")
graph.node("70", "Robert Slaney")
graph.node("71", "Zach Pochiro\n(Draft Pick)\nFree Agent)",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("72", "J.J. Piccinich\n(Draft Pick)\nFree Agent)",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("73", "Brandon McMillan\nFree Agent)",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("74", "Brett Lebda")
graph.node("75", "Zack Kassian\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("76", "Casey Staum\n(Draft Pick)\nFree Agent)",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("77", "Stefan Elliott\nFree Agent)",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("78", "Jay Bouwmeester")
graph.node("79", "Jordan Leopold")
graph.node("80", "Chris Butler")
graph.node("81", "Paul Byron\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("82", "Robin Regehr")
graph.node("83", "Jake McCabe\n(Draft Pick)\nToronto Maple Leafs",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("84", "Evan Oberg")
graph.node("85", "Cole Cassels\n(Draft Pick)\nFree Agent)",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("86", "Philip Holm")
graph.node("87", "Gabriel Carlsson\n(Draft Pick)\nWashington Capitals", fillcolor="#C8102E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("88", "Jeremy Bracco\n(Draft Pick)\nFree Agent)",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("89", "Ryan Parent")
graph.node("90", "Jonas Anderson")
graph.node("91", "Dan Gendur")
graph.node("92", "Alex Tanguay")
graph.node("93", "Cory Sarich")
graph.node("94", "David Jones")
graph.node("95", "Seth Griffith\n(Draft Pick)\nEdmonton Oilers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("96", "Benoit Pouliot")
graph.node("97", "Levi Nelson\nFree Agent)",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("98", "Tomas Vokoun")
graph.node("99", "Josh Bailey\n(Draft Pick)\nNew York Islanders",fillcolor="#00539B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("100", "Aaron Ness\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("101", "Patric Hornqvist\nFlorida Panthers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("102", "James Neal\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("103", "Scott Harrington\nAnaheim Ducks",fillcolor="#F47A38",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("104", "Kasperi Kapanen\nSt. Louis Blues",fillcolor="#002F87",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("105", "Sam Steel\n(Draft Pick)\nMinnesota Wild",fillcolor="#154734",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("106", "James Greenway\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("107", "Phil Kessel\nVegas Golden Knights",fillcolor="#B4975A",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("108", "Tyler Biggs")
graph.node("109", "Tim Erixon\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("110", "Raffi Torres")
graph.node("111", "Sean Durzi\n(Draft Pick)\nLos Angeles Kings",fillcolor="#572A84",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("112", "Roman Polak")
graph.node("113", "Max Comtois\n(Draft Pick)\nAnaheim Ducks",fillcolor="#F47A38",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("114", "William Karlsson\nVegas Golden Knights",fillcolor="#B4975A",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("115", "Kevin Stenlund\n(Draft Pick)\nWinnipeg Jets",fillcolor="#004C97",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("116", "James Wisniewski")
graph.node("117", "Brent Gates\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("118", "Steven Goertzen")
graph.node("119", "Brian McGrattan")
graph.node("120", "Patrick Mullen")
graph.node("121", "Roland McKeown\n(Draft Pick)\nNashville Predators",fillcolor="#FFB81C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("122", "Jason Garrison\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("123", "Jack Sadek\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("124", "Tobias Lindberg\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("125", "Erik Brannstrom\nOttawa Senators",fillcolor="#DA1A32",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("126", "Oscar Lindberg\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("127", "Yegor Sokolov\n(Draft Pick)\nOttawa Senators",fillcolor="#DA1A32",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("128", "Adam Hall")
graph.node("129", "Joel Vermin\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled",  width="3.0", height="3.0", fontsize="25")
graph.node("130", "Travis Hamonic\n(Draft Pick)\nOttawa Senators",fillcolor="#DA1A32",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("131", "Allan Rourke")
graph.node("132", "Tyler Myers\n(Draft Pick)\nVancouver Canucks",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("133", "Justin Schultz\n(Draft Pick)\nSeattle Kraken",fillcolor="#99D9D9",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("134", "Brayden Schenn\nSt. Louis Blues",fillcolor="#002F87",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("135", "Devin Shore\n(Draft Pick)\nEdmonton Oilers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("136", "Mike Richards")
graph.node("137", "Rob Bordson\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("138", "Ryan Hartman\nMinnesota Wild",fillcolor="#154734",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("139", "Thimo Nickl\n(Draft Pick)\nPittsburgh Penguins",fillcolor="#FCB514",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("140", "Topias Vilen\n(Draft Pick)\nNew Jersey Devils)",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("142", "Corey Fienhage\n(Draft Pick)")
graph.node("143", "Jeff Taffe")
graph.node("144", "Steven Kampfer\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("145", "Andrew Yogan\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("146", "Artem Anisimov\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("147", "Marko Dano\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("148", "Corey Tropp\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("149", "Brandon Saad\nSt. Louis Blues",fillcolor="#002F87",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("150", "Anatoli Golyshev\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("151", "Alex Broadhurst",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("152", "Michael Paliotta",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("153", "Richard Panik",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("154", "Alex Stalock",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("155", "Ben Smith",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("156", "Riley Stotts\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("157", "James Reimer",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("158", "Stefan Fournier",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("159", "Brendan Lemieux\nPhiladelphia Flyers",fillcolor="#F74902",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("160", "Ville Heinola\n(Draft Pick)\nWinnipeg Jets",fillcolor="#004C97",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("161", "Harrison Blaisdell\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("162", "Austen Brassard\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("163", "John Negrin",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("164", "Josiah Didier\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("165", "Brennan Serville\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("166", "Carter Verhaeghe",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("167", "Taylor Beck",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("168", "Tom Nilsson",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("169", "Matthew Finn",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("170", "Yegor Rykov",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("171", "Jonathan Tychonick\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("172", "Christopher Gibson",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("173", "Jesse Blacker",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("174", "Sebastian Repo\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("175", "Tye McGinn",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("176", "Michael Leighton",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("177", "Daniil Pylenkov\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("178", "Zane McIntyre",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("179", "Blake Geoffrion",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("180", "Dalton Thrower\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("181", "Hal Gill",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("182", "Patrik Bartosak\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("183", "Janne Juvonen\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("184", "Viktor Arvidsson\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("185", "Nail Yakupov",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("186", "Cameron Crotty\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("187", "Ben Scrivens",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("188", "Maverick Lamoureux\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("189", "2024 3rd Round\n(Draft Pick-Kassian)\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("190", "2025 2nd Round\n(Draft Pick-Kassian)\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("191", "Reid Schafer\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("192", "Jarred Tinordi",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("193", "Macoy Erkamps",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("194", "Ben Sexton",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("195", "Mark Cundari",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("196", "Reto Berra",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("197", "Emile Poirier\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("198", "Connor Brickley\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("199", "Justin Bailey\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("200", "Anthony Florentino\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("201", "Justin Falk",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("202", "Nolan Stevens\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("203", "Veeti Vainio",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("204", "Alex Lintuniemi\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("205", "Erik Cernak\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("206", "2025/26 1st Round\n(Draft Pick-McCabe\nChicago Blackhawks)",fillcolor="#CF0A2C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("207", "2026 2nd Round\n(Draft Pick-McCabe\nChicago Blackhawks)",fillcolor="#CF0A2C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("208", "2024/25 5th Round\n(Draft Pick-McCabe\nToronto Maple Leafs)",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("209", "Sam Lafferty",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("210", "Joey Anderson",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("211", "Pavel Gogolev",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("212", "Michael Kostka",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("213", "James Wright",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("214", "Mike Vernace",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("215", "David Booth",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("216", "Mikael Samuelsson",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("217", "Marco Sturm",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("218", "Steven Reinprecht",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("219", "Mikkel Boedker",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("220", "Connor Bleackley",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("221", "Kyle Wood",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("222", "Sergei Kostenko\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("223", "Colin Wilson\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("224", "Mike Matheson",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("225", "Colton Sceviour",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("226", "Milan Lucic",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("227", "Kirill Kirsanov\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("228", "Timo Meier",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("229", "Santeri Hatakka",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("230", "Timur Ibragimov",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("231", "Zachary Emond",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("232", "2024 5th Round\n(Draft Pick-Harrington\nNew Jersey Devils)",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("233", "Fabian Zetterlund",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("234", "Andreas Johnsson",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("235", "Nikita Okhotyuk",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("236", "Shakir Mukhamadullin",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("237", "2023/23 1st Round\n(Draft Pick-Harrington\nSan Jose Sharks)",fillcolor="#006D75",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("238", "2024 7th Round\n(Draft Pick-Harrington\nSan Jose Sharks)",fillcolor="#006D75",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("239", "Kerby Rychel",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("240", "2024 1st/2nd Round\n(Draft Pick-Harrington\nSan Jose Sharks)",fillcolor="#006D75",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("241", "Evan Rodrigues",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("242", "Filip Hallander",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("243", "David Warsofsky",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("244", "Rodion Amirov\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("245", "Pontus Aberg",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("246", "Jesper Lindgren",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("247", "Frederik Andersen",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("248", "Dane Birks",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("249", "Rasmus Korhonen\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("250", "Alex Galchenyuk",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("251", "Pierre-Olivier Joseph",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("252", "Carl Grundstrom",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("253", "Jake Muzzin",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("254", "Tobias Bjornfot\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("255", "David Clarkson",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("256", "Kristian Vesalainen\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("257", "Samuel Fagemo\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("258", "Anton Khudobin",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("259", "Stefan Chaput",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("260", "David Laliberte",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("261", "Sean Zimmerman",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("262", "Joe Piskula",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("263", "Conor Allen",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("264", "Linden Vey",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("265", "Julien Gauthier\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("266", "Nikita Gusev",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("267", "Alexandre Texier\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("268", "Paul Cotter\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("269", "Drake Caggiula",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("270", "Brandon Manning",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("271", "Robin Norell",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("272", "Brayden Point\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("273", "Louis Belpedio\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("274", "Lucas Feuk\n(Draft Pick)\nCalgary Flames",fillcolor="#D2001C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("275", "Noah Dobson\n(Draft Pick)\nNew York Islanders",fillcolor="#00539B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("276", "Ruslan Iskhakov\n(Draft Pick)\nNew York Islanders",fillcolor="#00539B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("277", "Samuel Bolduc\n(Draft Pick)\nNew York Islanders",fillcolor="#00539B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("278", "Elias Pettersson (2022)\n(Draft Pick)\nVancouver Canucks",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("279", "Colten Teubert\n(Draft Pick)")
graph.node("280", "Ryan Howse\n(Draft Pick)")
graph.node("281", "Jake Gardiner\n(Draft Pick)\nCarolina Hurricanes",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("282", "Drew Stafford")
graph.node("283", "Joel Armia\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("285", "Jack Roslovic\n(Draft Pick)\nWinnipeg Jets",fillcolor="#004C97",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("286", "Evander Kane\nEdmonton Oilers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("287", "Zach Bogosian\nTampa Bay Lightning",fillcolor="#002868",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("288", "Jason Kasdorf")
graph.node("289", "Dustin Penner")
graph.node("290", "Oscar Klefbom\n(Draft Pick)\nEdmonton Oilers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("291", "Daniil Zharkov\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("292", "Brent Moran\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("293", "Stephane Robidas")
graph.node("294", "Nicholas Deslauriers\n(Draft Pick)\nPhiladelphia Flyers",fillcolor="#F74902",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("295", "Garrett Wilson\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("296", "Brayden McNabb\nVegas Golden Knights",fillcolor="#B4975A",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("297", "Jonathan Parker")
graph.node("298", "Hudson Fasching\nNew York Islanders",fillcolor="#00539B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("299", "Zach Redmond\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("300", "Brandon Coe\n(Draft Pick)\nSan Jose Sharks",fillcolor="#006D75",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("301", "2023 3rd Round\n(Draft Pick-Deslauriers)\nAnaheim Ducks",fillcolor="#F47938",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("302", "Brock Beukeboom\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("303", "Wade Megan\n(Draft Pick)")
graph.node("304", "Jeff Halpern")
graph.node("305", "Teddy Purcell")
graph.node("306", "Jordan Binnington\n(Draft Pick)\nSt. Louis Blues",fillcolor="#002F87",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("307", "Eric Brewer")
graph.node("308", "Sam Gagner\nWinnipeg Jets",fillcolor="#004C97",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("309", "Matthew Cairns\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("310", "Dennis Yan\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("311", "Beck Malenstyn\n(Draft Pick)\nWashington Capitals",fillcolor="#C8102E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("312", "B.J. Crombeen")
graph.node("313", "Kristian Oldham\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("314", "Nicklas Grossmann")
graph.node("315", "Chris Pronger")
graph.node("316", "Otto Koivula\n(Draft Pick)\nNew York Islanders",fillcolor="#00539B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("317", "Ryan Spooner\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("318", "Andreas Athanasiou\nChicago Blackhawks)",fillcolor="#CF0A2C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("319", "Ryan Kuffner\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("320", "Brock Faber\n(Draft Pick)\nMinnesota Wild",fillcolor="#154734",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("321", "Aatu Raty\n(Draft Pick)\nVancouver Canucks",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("322", "Daniel Winnik\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("323", "Brooks Laich")
graph.node("324", "Connor Carrick\nBoston Bruins",fillcolor="#FFB81C",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("326", "MacKenzie Entwistle\n(Draft Pick)\nChicago Blackhawks",fillcolor="#CF0A2C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("327", "Maxim Letunov\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("328", "Jake McGrew\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("329", "Noel Hoefenmayer\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("330", "Marcus Kruger\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("331", "Jordan Maletta")
graph.node("332", "Andrew Campbell")
graph.node("333", "Marian Hossa")
graph.node("334", "Frederik Nissen Dichow\n(Draft Pick)\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("335", "Vinnie Hinostroza\nBuffalo Sabres",fillcolor="#003087",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("336", "Jordan Oesterle\nDetroit Red Wings",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("337", "Nathan Legare\n(Draft Pick)\nPittsburgh Penguins",fillcolor="#FCB514",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("338", "Dominik Kubalik\nDetroit Red Wings",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("339", "Nate Thompson\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("340", "Kim Nousiainen\n(Draft Pick)\nLos Angeles Kings",fillcolor="#572A84",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("341", "Daniil Sobolev\n(Draft Pick)\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("342", "Brad Morrison\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("343", "Matias Maccelli\n(Draft Pick)\nArizona Coyotes",fillcolor="#A94E13",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("344", "Valentin Nussbaumer\n(Draft Pick)\nArizona Coyotes",fillcolor="#A94E13",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("345", "Tarmo Reunanen\nCarolina Hurricanes",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("346", "Isaac Ratcliffe\n(Draft Pick)\nNashville Predators",fillcolor="#FFB81C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("347", "Nate Schnarr\n(Draft Pick)\nLos Angeles Kings",fillcolor="#572A84",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("348", "Filip Westerlund\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("349", "Future Considerations\n(Ratcliffe 2023)\nPhiladlephia Flyers",fillcolor="#F74902",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("350", "Taylor Hall\nBoston Bruins",fillcolor="#FFB81C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("351", "Blake Speers\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("352", "Nick Merkley\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("353", "Kevin Bahl\nNew Jersey Devils",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("354", "Dawson Mercer\n(Draft Pick)\nNew Jersey Devils",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("355", "Ryder Korczak\n(Draft Pick)\nNew York Rangers",fillcolor="#0038A8",style="filled", fontcolor="white",width="3.0", height="3.0", fontsize="25")
graph.node("356", "Andrew Hammond\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("357", "Frederic Allard\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("358", "Curtis Lazar\nNew Jersey Devils",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("359", "Anders Bjork\nChicago Blackhawks",fillcolor="#CF0A2C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("360", "Aleksandr Kisakov\n(Draft Pick)\nBuffalo Sabres",fillcolor="#003087",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("361", "2024 4th Round\n(Draft Pick)\nVancouver Canucks",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("362", "Future Considerations\n(Bjork 2023)\nBuffalo Sabres",fillcolor="#003087",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("363", "Christian Jaros\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("364", "Anthony Bitetto\nFlorida Panthers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("365", "Jonas Siegenthaler\nNew Jersey Devils",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("366", "Brent Johnson\n(Draft Pick)\nWashington Capitals", fillcolor="#C8102E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("367", "Dru Krebs\n(Draft Pick)\nWashington Capitals", fillcolor="#C8102E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("368", "Theodor Niederbach\n(Draft Pick)\nDetroit Red Wings",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("369", "Sam Stange\n(Draft Pick)\nDetroit Red Wings",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("370", "Kevin Fiala\nLos Angeles Kings",fillcolor="#572A84",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("371", "Liam Ohgren\n(Draft Pick)\nMinnesota Wild",fillcolor="#154734",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("372", "Nick Leddy\nSt. Louis Blues",fillcolor="#002F87",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("373", "Anthony Beauvilier\nVancouver Canucks",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("374", "Bo Horvat\nNew York Islanders",fillcolor="#00539B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("375", "2023/24 1st Round\n(Draft Pick-Raty)\nVancouver Canucks",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("376", "Luke Witkowski\nSt. Louis Blues",fillcolor="#002F87",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("377", "Oskar Sundqvist\nMinnesota Wild",fillcolor="#154734",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("378", "Jake Walman\nDetroit Red Wings",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("379", "2023 2nd Round\n(Draft Pick-Leddy)\nDetroit Red Wings",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("380", "2023 4th Round\n(Draft Pick-Sundqvist)\nDetroit Red Wings",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("381", "Ben Lovejoy")
graph.node("382", "Greame Clarke\n(Draft Pick)\nNew Jersey Devils)",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("383", "Francois Beauchemin")
graph.node("384", "Joffrey Lupul")
graph.node("385", "Fredrik Bergvik\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("386", "Carl Dahlstrom\n(Draft Pick)\nToronto Maple Leafs",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("387", "Fredrik Olofsson\n(Draft Pick)\nDallas Stars",fillcolor="#006847",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("388", "Dave Bolland")
graph.node("389", "Luc Snuggerud\n(Draft Pick)")
graph.node("390", "Gage Ausmus\n(Draft Pick)")
graph.node("391", "Noah Laba\n(Draft Pick)\nNew York Rangers",fillcolor="#0038A8",style="filled", fontcolor="white",width="3.0", height="3.0", fontsize="25")
graph.node("392", "Paul Stastny\nCarolina Hurricanes",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("393", "Brett Howden\nVegas Golden Knights)",fillcolor="#B4975A",style="filled", fontcolor="white",width="3.0", height="3.0", fontsize="25")
graph.node("394", "Nick DeSimone\nCalgary Flames",fillcolor="#D2001C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("395", "Lawson Crouse\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("396", "Max Gildon\n(Draft Pick)\nFlorida Panthers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("397", "Serron Noel\n(Draft Pick)\nFlorida Panthers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("398", "Declan Chisholm\n(Draft Pick)\nWinnipeg Jets",fillcolor="#004C97",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("399", "Steve Mason")
graph.node("400", "Kieran Ruscheinski\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("401", "Jack Smith\n(Draft Pick)\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("402", "Simon Bourque\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("403", "Brody Lamb\n(Draft Pick)\nNew York Rangers",fillcolor="#0038A8",style="filled", fontcolor="white",width="3.0", height="3.0", fontsize="25")
graph.node("404", "Zack MacEwen\nLos Angeles Kings",fillcolor="#572A84",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("405", "2024 5th Round\n(Draft Pick\Lemieux)\nPhiladelphia Flyers",fillcolor="#F74902",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("406", "Jacob Trouba\nNew York Rangers",fillcolor="#0038A8",style="filled", fontcolor="white",width="3.0", height="3.0", fontsize="25")
graph.node("407", "Neal Pionk\nWinnipeg Jets",fillcolor="#004C97",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("408", "Patrick Laine\nColumbus Blue Jackets",fillcolor="#002654",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("409", "Pierre-Luc Dubois\nWinnipeg Jets",fillcolor="#004C97",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("410", "Danil Zhilkin\n(Draft Pick)\nWinnipeg Jets",fillcolor="#004C97",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("411", "Danny O'Regan\nDetroit Red Wings",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("412", "Brayden Tracey\n(Draft Pick)\nAnaheim Ducks",fillcolor="#F47A38",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("413", "Ethan Keppen\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("414", "Michael Del Zotto\nAnaheim Ducks",fillcolor="#F47A38",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("415", "Givani Smith\nFlorida Panthers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("416", "Brendan Guhle\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("417", "Brandon Montour\nFlorida Panthers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("418", "Stiven Sardarian\n(Draft Pick)\nBuffalo Sabres",fillcolor="#003087",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("419", "Karel Plasek\n(Draft Pick)\nVancouver Canucks",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("420", "Aaron Huglen\n(Draft Pick)\nBuffalo Sabres",fillcolor="#003087",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("421", "Filip Berglund\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("422", "Jori Lehtera\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("423", "Joel Farabee\n(Draft Pick)\nPhiladelphia Flyers",fillcolor="#F74902",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("424", "Morgan Frost\n(Draft Pick)\nPhiladelphia Flyers",fillcolor="#F74902",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("425", "Jake Guentzel\n(Draft Pick)\nPittsburgh Penguins",fillcolor="#FCB514",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("426", "Andrew Cogliano\nColorado Avalanche",fillcolor="#6F263D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("427", "Sonny Milano\nWashington Capitals", fillcolor="#C8102E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("428", "Joe Morrow\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("429", "Brenden Morrow")
graph.node("430", "Matel Paulovic\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("431", "Reilly Smith\nVegas Golden Knights",fillcolor="#B4975A",style="filled", fontcolor="white",width="3.0", height="3.0", fontsize="25")
graph.node("432", "Matt Fraser\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("433", "Tyler Seguin\nDallas Stars",fillcolor="#006847",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("434", "Rich Peverley")
graph.node("435", "Ryan Button\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("436", "Milos Roman\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("437", "Loui Eriksson\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("438", "Jimmy Hayes")
graph.node("439", "Marc Savard")
graph.node("440", "Jack Gorniak\n(Draft Pick)\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("441", "Martin Fehervary\n(Draft Pick)\nWashington Capitals", fillcolor="#C8102E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("442", "Paul Thompson\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("443", "Graham Black")
graph.node("444", "Linus Karlsson\n(Draft Pick)\nVancouver Canucks",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("445", "Marcus Johansson\nMinnesota Wild",fillcolor="#154734",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("446", "Michal Kempny\nSeattle Kraken",fillcolor="#99D9D9",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("447", "Niklas Nordgren\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("448", "Michael Callahan\n(Draft Pick)\nBoston Bruins",fillcolor="#FFB81C",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("449", "Ivan Prosvetov\n(Draft Pick)\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("450", "Dennis Busby\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("451", "Jonathan Dahlen\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("452", "2024 7th Round\n(Draft Pick-Callahan)\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("453", "Ethan Edwards\n(Draft Pick)\nNew Jersey Devils)",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("454", "Eric Staal\nFlorida Panthers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("455", "Daniel Sprong\nSeattle Kraken",fillcolor="#99D9D9",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("456", "Cole Spicer\n(Draft Pick)\nBoston Bruins",fillcolor="#FFB81C",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("457", "2023 6th Round\n(Draft Pick-Johansson)\nSeattle Kraken",fillcolor="#99D9D9",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("458", "2024 3rd Round\n(Draft Pick-Johansson)\nWashington Capitals", fillcolor="#C8102E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("459", "Josh Bloom\n(Draft Pick)\nVancouver Canucks",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("460", "Viljami Marjala\n(Draft Pick)\nBuffalo Sabres",fillcolor="#003087",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("461", "Riley Stillman\nBuffalo Sabres",fillcolor="#003087",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("462", "Frederic Brunet\n(Draft Pick)\nBoston Bruins",fillcolor="#FFB81C",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("463", "Ben MacDonald\n(Draft Pick)\nSeattle Kraken",fillcolor="#99D9D9",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("464", "Mike Hoffman\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("465", "Santtu Kinnunen\n(Draft Pick)\nFlorida Panthers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("466", "Mikael Hakkarainen\n(Draft Pick)")
graph.node("467", "Jamieson Rees\n(Draft Pick)\nCarolina Hurricanes",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("468", "Jasper Weatherby\n(Draft Pick)\nDetroit Red Wings",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("469", "Henrik Rybinski\n(Draft Pick)\nWashington Capitals", fillcolor="#C8102E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("470", "Marc-Andre Fleury\nMinnesota Wild",fillcolor="#154734",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("471", "Jakub Dobes\n(Draft Pick)\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("472", "Ryan Greene\n(Draft Pick)\nChicago Blackhawks)",fillcolor="#CF0A2C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("473", "Chris Tierney\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("474", "Rudolfs Balcers\nTampa Bay Lightning",fillcolor="#002868",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("475", "Josh Norris\nOttawa Senators",fillcolor="#DA1A32",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("476", "Dylan Demelo\nWinnipeg Jets",fillcolor="#004C97",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("477", "Tim Stuetzle\n(Draft Pick)\nOttawa Senators",fillcolor="#DA1A32",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("478", "Zack Ostapchuk\n(Draft Pick)\nOttawa Senators",fillcolor="#DA1A32",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("479", "Erik Karlsson\nSan Jose Sharks",fillcolor="#006D75",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("480", "Francis Perron\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("481", "Anttoni Honka\n(Draft Pick)\nCarolina Hurricanes",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("482", "Mads Sogaard\n(Draft Pick)\nOttawa Senators",fillcolor="#DA1A32",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("483", "Leevi Merilainen\n(Draft Pick)\nOttawa Senators",fillcolor="#DA1A32",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("484", "Arvid Costmar\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("485", "Tom Pyatt")
graph.node("486", "Kyle Criscuolo\nSan Jose Sharks)",fillcolor="#006D75",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("487", "Andrew Ladd\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("488", "Jay Harrison")
graph.node("489", "German Rubtsov\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("490", "J.J. Moser\n(Draft Pick)\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("491", "Mattias Havelid\n(Draft Pick)\nSan Jose Sharks)",fillcolor="#006D75",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("492", "2023 Cond 3rd Round\n(Draft Pick-Ladd)\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("493", "Conor Geekie\n(Draft Pick)\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("494", "Filip Bystedt\n(Draft Pick)\nSan Jose Sharks)",fillcolor="#006D75",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("495", "Cameron Lund\n(Draft Pick)\nSan Jose Sharks)",fillcolor="#006D75",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("496", "Owen Tippett\nPhiladelphia Flyers",fillcolor="#F74902",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("497", "2023 3rd Round\n(Draft Pick-Rubtsov)\nPhiladelphia Flyers",fillcolor="#F74902",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("498", "2024/25 1st Round\n(Draft Pick-Rubtsov)\nPhiladelphia Flyers",fillcolor="#F74902",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("499", "Claude Giroux\nOttawa Senators",fillcolor="#DA1A32",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("500", "Connor Bunnaman\nFlorida Panthers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("501", "2024 5th Round\n(Draft Pick-Rubtsov)\nFlorida Panthers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("502", "2023 7th Round\n(Draft Pick-Eriksson)\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("503", "Oliver Ekman-Larsson",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("503", "Conor Garland\nVancouver Canucks",fillcolor="#00205B",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("504", "Jay Beagle\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("505", "Antoine Roussel")
graph.node("506", "Dylan Guenther\n(Draft Pick)\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("507", "Hunter Haight\n(Draft Pick)\nMinnesota Wild",fillcolor="#154734",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("508", "Jack McBain\nArizona Coyotes",fillcolor="#A9431E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("509", "2024 5th Round\n(Draft Pick-Cogliano)\nSan Jose Sharks)",fillcolor="#006D75",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("510", "Tyler Pitlick\nSt. Louis Blues",fillcolor="#002F87",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("511", "Emil Heineman\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("512", "Filip Mesar\n(Draft Pick)\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("513", "Tyler Toffoli\nCalgary Flames",fillcolor="#D2001C",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("514", "2023 5th Round\n(Draft Pick-Pitlick)\nMontreal Canadiens",fillcolor="#AF1E2D",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("515", "Derek Grant\nAnaheim Ducks",fillcolor="#F47A38",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("516", "Judd Caulfield\nAnaheim Ducks",fillcolor="#F47A38",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("517", "Future Considerations\n(Kampfer 2023)\nDetroit Red Wings",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("518", "Dylan McIlrath\nWashington Capitals", fillcolor="#C8102E",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("519", "Cade Webber\n(Draft Pick)\nCarolina Hurricanes",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("520", "Jake Schmaltz\n(Draft Pick)\nBoston Bruins",fillcolor="#FFB81C",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("521", "Adam McQuaid")
graph.node("522", "Kasper Kotkansalo\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("523", "Charlie Coyle\nBoston Bruins",fillcolor="#FFB81C",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("524", "Ryan Donato\nSeattle Kraken",fillcolor="#99D9D9",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("525", "Patrik Puistola\n(Draft Pick)\nEdmonton Oilers",fillcolor="#041E42",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("526", "Hunter Jones\n(Draft Pick)\nMinnesota Wild",fillcolor="#154734",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("527", "Jesse Puljujarvi\nCarolina Hurricanes",fillcolor="#CE1126",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("528", "Julius Bergman\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("529", "Hunter Skinner\n(Draft Pick)\nSt. Louis Blues",fillcolor="#002F87",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("530", "Eric Ciccolini\n(Draft Pick)\nNew York Rangers",fillcolor="#0038A8",style="filled", fontcolor="white",width="3.0", height="3.0", fontsize="25")
graph.node("531", "2023 1st Round\n(Draft Pick-Skinner)\nSt. Louis Blues",fillcolor="#002F87",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("532", "2024 3rd Round\n(Draft Pick-Skinner)\nSt. Louis Blues",fillcolor="#002F87",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("533", "Sammy Blais\nSt. Louis Blues",fillcolor="#002F87",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("534", "Vladimir Tarasenko\nNew York Rangers",fillcolor="#0038A8",style="filled", fontcolor="white",width="3.0", height="3.0", fontsize="25")
graph.node("535", "Niko Makkola\nNew York Rangers",fillcolor="#0038A8",style="filled", fontcolor="white",width="3.0", height="3.0", fontsize="25")
graph.node("536", "Zack Smith")
graph.node("537", "Tim Jackman")
graph.node("538", "Joshua Ess\n(Draft Pick)\nFree Agent",fillcolor="#00FF00",style="filled", width="3.0", height="3.0", fontsize="25")
graph.node("539", "Anton Forsberg\nOttawa Senators",fillcolor="#DA1A32",style="filled", fontcolor="white", width="3.0", height="3.0", fontsize="25")
graph.node("540", "Artemi Panarin",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("541", "Tyler Motte",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("542", "Jonathan Davidsson\n(Draft Pick)",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("543", "Dennis Gilbert",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("544", "Anton Lindholm",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("545", "Nikita Zadorov",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("546", "Calvin de Haan",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("547", "Aleksi Saarela",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("548", "Gustav Forsling",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")
graph.node("", "",fillcolor="#",style="filled", fontcolor="white", width="", height="", fontsize="")





##
graph.edge("1", "2")
graph.edge("1", "3")
graph.edge("1", "4")
graph.edge("1", "5")
graph.edge("1", "6")
graph.edge("1", "7")
graph.edge("1", "8")
graph.edge("1", "9")
graph.edge("1", "10")
graph.edge("1", "11")
graph.edge("1", "12")
graph.edge("2", "13")
graph.edge("2", "14")
graph.edge("2", "15")
graph.edge("3", "16")
graph.edge("3", "17")
graph.edge("4", "18")
graph.edge("4", "19")
graph.edge("4", "20")
graph.edge("4", "21")
graph.edge("4", "22")
graph.edge("4", "23")
graph.edge("4", "24")
graph.edge("4", "25")
graph.edge("4", "26")
graph.edge("4", "28")
graph.edge("4", "29")
graph.edge("4", "30")
graph.edge("4", "31")
graph.edge("4", "32")
graph.edge("4", "33")
graph.edge("5", "34")
graph.edge("5", "35")
graph.edge("5", "36")
graph.edge("6", "37")
graph.edge("7", "38")
graph.edge("8", "39")
graph.edge("8", "40")
graph.edge("9", "41")
graph.edge("9", "42")
graph.edge("9", "43")
graph.edge("11", "44")
graph.edge("11", "45")
graph.edge("13", "46")
graph.edge("13", "47")
graph.edge("13", "48")
graph.edge("15", "49")
graph.edge("15", "50")
graph.edge("15", "51")
graph.edge("15", "52")
graph.edge("15", "53")
graph.edge("15", "54")
graph.edge("15", "55")
graph.edge("15", "56")
graph.edge("15", "57")
graph.edge("15", "58")
graph.edge("15", "59")
graph.edge("15", "60")
graph.edge("15", "61")
graph.edge("18", "62")
graph.edge("18", "63")
graph.edge("18", "64")
graph.edge("18", "65")
graph.edge("20", "66")
graph.edge("20", "67")
graph.edge("20", "68")
graph.edge("21", "70")
graph.edge("21", "71")
graph.edge("21", "72")
graph.edge("21", "73")
graph.edge("21", "74")
graph.edge("22", "75")
graph.edge("22", "76")
graph.edge("23", "77")
graph.edge("24", "78")
graph.edge("24", "79")
graph.edge("25", "80")
graph.edge("25", "81")
graph.edge("25", "82")
graph.edge("25", "83")
graph.edge("26", "84")
graph.edge("26", "85")
graph.edge("28", "86")
graph.edge("33", "87")
graph.edge("33", "88")
graph.edge("34", "89")
graph.edge("34", "90")
graph.edge("34", "91")
graph.edge("34", "92")
graph.edge("34", "93")
graph.edge("34", "94")
graph.edge("35", "95")
graph.edge("35", "96")
graph.edge("36", "97")
graph.edge("38", "98")
graph.edge("38", "99")
graph.edge("38", "100")
graph.edge("38", "101")
graph.edge("38", "102")
graph.edge("38", "103")
graph.edge("38", "104")
graph.edge("38", "105")
graph.edge("38", "106")
graph.edge("38", "107")
graph.edge("38", "108")
graph.edge("38", "109")
graph.edge("38", "110")
graph.edge("38", "111")
graph.edge("38", "112")
graph.edge("38", "113")
graph.edge("40", "114")
graph.edge("40", "115")
graph.edge("40", "116")
graph.edge("40", "117")
graph.edge("41", "118")
graph.edge("42", "119")
graph.edge("42", "120")
graph.edge("42", "121")
graph.edge("42", "122")
graph.edge("42", "123")
graph.edge("43", "124")
graph.edge("43", "125")
graph.edge("43", "126")
graph.edge("43", "127")
graph.edge("46", "128")
graph.edge("46", "129")
graph.edge("47", "130")
graph.edge("47", "131")
graph.edge("47", "132")
graph.edge("47", "133")
graph.edge("49", "134")
graph.edge("49", "135")
graph.edge("49", "136")
graph.edge("49", "137")
graph.edge("49", "138")
graph.edge("49", "139")
graph.edge("49", "140")
graph.edge("50", "142")
graph.edge("51", "143")
graph.edge("52", "144")
graph.edge("52", "145")
graph.edge("53", "146")
graph.edge("53", "147")
graph.edge("53", "148")
graph.edge("53", "149")
graph.edge("53", "150")
graph.edge("53", "151")
graph.edge("53", "152")
graph.edge("53", "153")
graph.edge("53", "154")
graph.edge("53", "155")
graph.edge("53", "156")
graph.edge("53", "157")
graph.edge("53", "158")
graph.edge("54", "159")
graph.edge("54", "160")
graph.edge("54", "161")
graph.edge("57", "162")
graph.edge("58", "163")
graph.edge("61", "164")
graph.edge("61", "165")
graph.edge("64", "166")
graph.edge("64", "167")
graph.edge("64", "168")
graph.edge("64", "169")
graph.edge("64", "170")
graph.edge("64", "171")
graph.edge("64", "172")
graph.edge("67", "173")
graph.edge("67", "174")
graph.edge("68", "175")
graph.edge("68", "176")
graph.edge("68", "177")
graph.edge("68", "178")
graph.edge("70", "179")
graph.edge("70", "180")
graph.edge("70", "181")
graph.edge("70", "182")
graph.edge("71", "183")
graph.edge("71", "184")
graph.edge("71", "185")
graph.edge("71", "186")
graph.edge("75", "187")
graph.edge("75", "188")
graph.edge("75", "189")
graph.edge("75", "190")
graph.edge("75", "191")
graph.edge("77", "192")
graph.edge("77", "193")
graph.edge("77", "194")
graph.edge("78", "195")
graph.edge("78", "196")
graph.edge("78", "197")
graph.edge("79", "198")
graph.edge("79", "199")
graph.edge("79", "200")
graph.edge("79", "201")
graph.edge("79", "202")
graph.edge("80", "203")
graph.edge("82", "204")
graph.edge("82", "205")
graph.edge("83", "206")
graph.edge("83", "207")
graph.edge("83", "208")
graph.edge("83", "209")
graph.edge("83", "210")
graph.edge("83", "211")
graph.edge("84", "212")
graph.edge("84", "213")
graph.edge("84", "214")
graph.edge("85", "215")
graph.edge("85", "216")
graph.edge("85", "217")
graph.edge("85", "218")
graph.edge("92", "219")
graph.edge("92", "220")
graph.edge("92", "221")
graph.edge("98", "222")
graph.edge("99", "223")
graph.edge("101", "224")
graph.edge("101", "225")
graph.edge("102", "226")
graph.edge("102", "227")
graph.edge("103", "228")
graph.edge("103", "229")
graph.edge("103", "230")
graph.edge("103", "231")
graph.edge("103", "232")
graph.edge("103", "233")
graph.edge("103", "234")
graph.edge("103", "235")
graph.edge("103", "236")
graph.edge("103", "237")
graph.edge("103", "238")
graph.edge("103", "239")
graph.edge("103", "240")
graph.edge("104", "241")
graph.edge("104", "242")
graph.edge("104", "243")
graph.edge("104", "244")
graph.edge("104", "245")
graph.edge("104", "246")
graph.edge("105", "247")
graph.edge("107", "248")
graph.edge("107", "249")
graph.edge("107", "250")
graph.edge("107", "251")
graph.edge("111", "252")
graph.edge("111", "253")
graph.edge("111", "254")
graph.edge("114", "255")
graph.edge("114", "256")
graph.edge("114", "257")
graph.edge("116", "258")
graph.edge("119", "259")
graph.edge("119", "260")
graph.edge("119", "261")
graph.edge("119", "262")
graph.edge("120", "263")
graph.edge("121", "264")
graph.edge("121", "265")
graph.edge("122", "266")
graph.edge("122", "267")
graph.edge("122", "268")
graph.edge("122", "269")
graph.edge("122", "270")
graph.edge("122", "271")
graph.edge("123", "272")
graph.edge("123", "273")
graph.edge("130", "274")
graph.edge("130", "275")
graph.edge("130", "276")
graph.edge("130", "277")
graph.edge("130", "278")
graph.edge("132", "279")
graph.edge("132", "280")
graph.edge("132", "281")
graph.edge("132", "282")
graph.edge("132", "283")
graph.edge("132", "285")
graph.edge("132", "286")
graph.edge("132", "287")
graph.edge("132", "288")
graph.edge("279", "289")
graph.edge("279", "290")
graph.edge("279", "291")
graph.edge("289", "292")
graph.edge("292", "293")
graph.edge("280", "294")
graph.edge("280", "295")
graph.edge("294", "296")
graph.edge("294", "297")
graph.edge("294", "298")
graph.edge("294", "299")
graph.edge("294", "300")
graph.edge("294", "301")
graph.edge("295", "302")
graph.edge("295", "303")
graph.edge("302", "304")
graph.edge("302", "305")
graph.edge("302", "306")
graph.edge("302", "307")
graph.edge("305", "308")
graph.edge("305", "309")
graph.edge("307", "310")
graph.edge("307", "311")
graph.edge("308", "312")
graph.edge("308", "313")
graph.edge("308", "314")
graph.edge("308", "315")
graph.edge("308", "316")
graph.edge("308", "317")
graph.edge("308", "318")
graph.edge("308", "319")
graph.edge("308", "320")
graph.edge("308", "321")
graph.edge("311", "322")
graph.edge("311", "323")
graph.edge("311", "324")
graph.edge("316", "326")
graph.edge("316", "327")
graph.edge("316", "328")
graph.edge("316", "329")
graph.edge("326", "330")
graph.edge("326", "331")
graph.edge("326", "332")
graph.edge("326", "333")
graph.edge("326", "334")
graph.edge("326", "335")
graph.edge("326", "336")
graph.edge("326", "337")
graph.edge("334", "338")
graph.edge("334", "339")
graph.edge("334", "340")
graph.edge("339", "341")
graph.edge("335", "342")
graph.edge("337", "343")
graph.edge("337", "344")
graph.edge("327", "345")
graph.edge("329", "346")
graph.edge("329", "347")
graph.edge("329", "348")
graph.edge("346", "349")
graph.edge("347", "350")
graph.edge("347", "351")
graph.edge("347", "352")
graph.edge("347", "353")
graph.edge("347", "354")
graph.edge("347", "355")
graph.edge("347", "356")
graph.edge("347", "357")
graph.edge("350", "358")
graph.edge("350", "359")
graph.edge("350", "360")
graph.edge("358", "361")
graph.edge("359", "362")
graph.edge("352", "363")
graph.edge("352", "364")
graph.edge("355", "365")
graph.edge("355", "366")
graph.edge("356", "367")
graph.edge("320", "368")
graph.edge("320", "369")
graph.edge("320", "370")
graph.edge("320", "371")
graph.edge("321", "372")
graph.edge("321", "373")
graph.edge("321", "374")
graph.edge("321", "375")
graph.edge("372", "376")
graph.edge("372", "377")
graph.edge("372", "378")
graph.edge("372", "379")
graph.edge("377", "380")
graph.edge("324", "381")
graph.edge("324", "382")
graph.edge("281", "383")
graph.edge("281", "384")
graph.edge("281", "385")
graph.edge("385", "386")
graph.edge("385", "387")
graph.edge("385", "388")
graph.edge("385", "389")
graph.edge("385", "390")
graph.edge("386", "391")
graph.edge("386", "392")
graph.edge("391", "393")
graph.edge("391", "394")
graph.edge("388", "395")
graph.edge("388", "396")
graph.edge("388", "397")
graph.edge("282", "398")
graph.edge("283", "399")
graph.edge("283", "400")
graph.edge("283", "401")
graph.edge("283", "402")
graph.edge("159", "403")
graph.edge("159", "404")
graph.edge("159", "405")
graph.edge("160", "406")
graph.edge("160", "407")
graph.edge("285", "408")
graph.edge("285", "409")
graph.edge("285", "410")
graph.edge("286", "411")
graph.edge("286", "412")
graph.edge("286", "413")
graph.edge("411", "414")
graph.edge("411", "415")
graph.edge("412", "416")
graph.edge("412", "417")
graph.edge("417", "418")
graph.edge("413", "419")
graph.edge("413", "420")
graph.edge("133", "421")
graph.edge("134", "422")
graph.edge("134", "423")
graph.edge("134", "424")
graph.edge("135", "425")
graph.edge("135", "426")
graph.edge("135", "427")
graph.edge("425", "428")
graph.edge("425", "429")
graph.edge("425", "430")
graph.edge("428", "431")
graph.edge("428", "432")
graph.edge("428", "433")
graph.edge("428", "434")
graph.edge("428", "435")
graph.edge("428", "436")
graph.edge("428", "437")
graph.edge("431", "438")
graph.edge("431", "439")
graph.edge("431", "440")
graph.edge("439", "441")
graph.edge("439", "442")
graph.edge("439", "443")
graph.edge("441", "444")
graph.edge("441", "445")
graph.edge("444", "446")
graph.edge("444", "447")
graph.edge("444", "448")
graph.edge("444", "449")
graph.edge("444", "450")
graph.edge("444", "451")
graph.edge("448", "452")
graph.edge("445", "453")
graph.edge("445", "454")
graph.edge("445", "455")
graph.edge("445", "456")
graph.edge("445", "457")
graph.edge("445", "458")
graph.edge("454", "459")
graph.edge("454", "460")
graph.edge("459", "461")
graph.edge("456", "462")
graph.edge("456", "463")
graph.edge("440", "464")
graph.edge("440", "465")
graph.edge("440", "466")
graph.edge("440", "467")
graph.edge("440", "468")
graph.edge("466", "469")
graph.edge("466", "470")
graph.edge("469", "471")
graph.edge("470", "472")
graph.edge("467", "473")
graph.edge("467", "474")
graph.edge("467", "475")
graph.edge("467", "476")
graph.edge("467", "477")
graph.edge("467", "478")
graph.edge("467", "479")
graph.edge("467", "480")
graph.edge("467", "481")
graph.edge("467", "482")
graph.edge("476", "483")
graph.edge("480", "484")
graph.edge("480", "485")
graph.edge("468", "486")
graph.edge("432", "487")
graph.edge("432", "488")
graph.edge("432", "489")
graph.edge("487", "490")
graph.edge("487", "491")
graph.edge("487", "492")
graph.edge("491", "493")
graph.edge("491", "494")
graph.edge("491", "495")
graph.edge("489", "496")
graph.edge("489", "497")
graph.edge("489", "498")
graph.edge("489", "499")
graph.edge("489", "500")
graph.edge("489", "501")
graph.edge("437", "502")
graph.edge("437", "503")
graph.edge("437", "504")
graph.edge("437", "505")
graph.edge("437", "506")
graph.edge("437", "507")
graph.edge("507", "508")
graph.edge("426", "509")
graph.edge("138", "510")
graph.edge("510", "511")
graph.edge("510", "512")
graph.edge("510", "513")
graph.edge("510", "514")
graph.edge("139", "515")
graph.edge("139", "516")
graph.edge("144", "517")
graph.edge("144", "518")
graph.edge("144", "519")
graph.edge("144", "520")
graph.edge("144", "521")
graph.edge("518", "522")
graph.edge("519", "523")
graph.edge("519", "524")
graph.edge("519", "525")
graph.edge("519", "526")
graph.edge("525", "527")
graph.edge("521", "528")
graph.edge("521", "529")
graph.edge("521", "530")
graph.edge("529", "531")
graph.edge("529", "532")
graph.edge("529", "533")
graph.edge("529", "534")
graph.edge("529", "535")
graph.edge("146", "536")
graph.edge("148", "537")
graph.edge("148", "538")
graph.edge("149", "539")
graph.edge("149", "540")
graph.edge("149", "541")
graph.edge("149", "542")
graph.edge("149", "543")
graph.edge("149", "544")
graph.edge("149", "545")
graph.edge("539", "546")
graph.edge("539", "547")
graph.edge("539", "548")

# %%
graph.render('Roberto Luongo', format='svg')
# Out:
# ...
# 'Roberto Luongo.svg'
